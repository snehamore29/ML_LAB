# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv("Cancer_data.csv")

# %%
df.head()
# Out:
#    Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0   58       1  16.085313        0            1          8.146251
# 1   71       0  30.828784        0            1          9.361630
# 2   48       1  38.785084        0            2          5.135179
# 3   34       0  30.040296        0            0          9.502792
# 4   62       1  35.479721        0            0          5.356890
#
#    AlcoholIntake  CancerHistory  Diagnosis
# 0       4.148219              1          1
# 1       3.519683              0          0
# 2       4.728368              0          1
# 3       2.044636              0          0
# 4       3.309849              0          1

# %%
feat_cols = ['Age', 'Gender', 'Smoking']
X = df[feat_cols] 
y = df.CancerHistory

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
cd= DecisionTreeClassifier()
cd = cd.fit(X_train,y_train)
y_pred = cd.predict(X_test)

# %%
Acc=metrics.accuracy_score(y_test,y_pred)

print("Acurracy:",Acc)
# Out:
# Acurracy: 0.8488888888888889

# %%
from sklearn.tree import export_graphviz
import graphviz


dot_data = export_graphviz(cd, feature_names=feat_cols, class_names=['cancer', 'No_cancer'])
graphviz.Source(dot_data)
